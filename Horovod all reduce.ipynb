# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/DISML/Project
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/DISML/Project

# %%
# !gunzip -c openmpi-4.1.0.tar.gz | tar xf -

# %%
# !export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:"path/to/your/libtensorflow"

# %%
# !apt install mpich

# %%
# !horovodrun -np 1 -H localhost:4 python /content/drive/MyDrive/DISML/Project/tensorflow_mnist.py

# %%
# !pip install --upgrade pip setuptools wheel
# !pip install -I tensorflow
# !pip install -I keras

# %%
# !pip3 install mpi4py

# %%
# !pip install horovod

# %%
# !horovodrun --gloo -np 2 python /content/drive/MyDrive/DISML/Project/horvod_pytorch.py

# %%
# !horovodrun -np 4 --fusion-threshold-mb 32 python /content/drive/MyDrive/DISML/Project/horvod_pytorch.py
