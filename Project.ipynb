# %%
# !git clone https://github.com/wenwei202/terngrad

# %%
# %cd /content/drive/MyDrive/DISML/Project
# %env PYTHONPATH="$/env/python::/content/drive/MyDrive/DISML/Project"
# !echo $PYTHONPATH

# %%
# %cd /content/drive/MyDrive/DISML/Project/terngrad/terngrad/
# Out:
# /content/drive/MyDrive/DISML/Project/terngrad/terngrad

# %%
# !./build_all.sh

# %%
# !apt install apt-transport-https curl gnupg
# !curl -fsSL https://bazel.build/bazel-release.pub.gpg | gpg --dearmor > bazel.gpg
# !mv bazel.gpg /etc/apt/trusted.gpg.d/
# !echo "deb [arch=amd64] https://storage.googleapis.com/bazel-apt stable jdk1.8" | sudo tee /etc/apt/sources.list.d/bazel.list


# !apt install bazel-1.0.0
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# curl is already the newest version (7.58.0-2ubuntu3.12).
# gnupg is already the newest version (2.2.4-1ubuntu1.4).
# apt-transport-https is already the newest version (1.6.12ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.
# deb [arch=amd64] https://storage.googleapis.com/bazel-apt stable jdk1.8
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package bazel-1.0.0
# E: Couldn't find any package by glob 'bazel-1.0.0'
# E: Couldn't find any package by regex 'bazel-1.0.0'

# %%
# !apt-get install pkg-config zip g++ zlib1g-dev unzip python3

# %%
# !chmod 755 -R /content/drive/MyDrive/DISML/Project/

# %%
BAZEL_VERSION = '0.20.0'
# !wget https://github.com/bazelbuild/bazel/releases/download/{BAZEL_VERSION}/bazel-{BAZEL_VERSION}-installer-linux-x86_64.sh
# !chmod +x bazel-{BAZEL_VERSION}-installer-linux-x86_64.sh
# !./bazel-{BAZEL_VERSION}-installer-linux-x86_64.sh

# %%
#!export PATH="$PATH:$HOME/bin:/root/bin"
# !bazel

# %%
# !./build_all.sh

# %%
# %cd /content/drive/MyDrive/DISML/Project/terngrad/slim
# Out:
# /content/drive/MyDrive/DISML/Project/terngrad/slim

# %%
# !pip install pickle-mixin

# %%
# !export DATA_PATH="${HOME}/dataset/mnist-data/"
# !python download_and_convert_data.py --dataset_name mnist --dataset_dir ${DATA_PATH} -1

# %%
# %tensorflow_version 1.1.0
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.1.0`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
# !export DATA_PATH="${HOME}/dataset/cifar10-data/" # the directory of database
# !python download_and_convert_data.py --dataset_name cifar10 --dataset_dir ${DATA_PATH} -1

# %%
# !export DATA_PATH="${HOME}/dataset/cifar10-shard-data/" # the directory of database
# !python download_and_convert_data.py \--dataset_name cifar10 \--dataset_dir ${DATA_PATH} \--shard True

# %%
# %cd /content/drive/MyDrive/DISML/Project/terngrad/terngrad/
# Out:
# /content/drive/MyDrive/DISML/Project/terngrad/terngrad

# %%
# !./run_multi_gpus_cifar10.sh

# %%
# !pip install pyro[horovod]
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/61/68/0978adae315261b87acd216517c2c7f00780396e4d1426c5412458c6a28f/Pyro-3.16.tar.gz
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
