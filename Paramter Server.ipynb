# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/DISML/Project/PyTorch-parameter-server
# !pip install mpi4py
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/DISML/Project/PyTorch-parameter-server
# Collecting mpi4py
#   Downloading https://files.pythonhosted.org/packages/ec/8f/bbd8de5ba566dd77e408d8136e2bab7fdf2b97ce06cab830ba8b50a2f588/mpi4py-3.0.3.tar.gz (1.4MB)
#      |████████████████████████████████| 1.4MB 6.2MB/s
# Building wheels for collected packages: mpi4py
#   Building wheel for mpi4py (setup.py) ... done
#   Created wheel for mpi4py: filename=mpi4py-3.0.3-cp37-cp37m-linux_x86_64.whl size=2065207 sha256=3641cad0513ea9f52732a1845c801a692afdbe6548ea270209ff981821de8523
#   Stored in directory: /root/.cache/pip/wheels/18/e0/86/2b713dd512199096012ceca61429e12b960888de59818871d6
# Successfully built mpi4py
# Installing collected packages: mpi4py
# Successfully installed mpi4py-3.0.3

# %%
#!pip3 install torch==1.5.1+cu101 torchvision==0.6.1+cu101 -f https://download.pytorch.org/whl/torch_stable.html
# !pip3 install torch==1.5.1+cpu torchvision==0.6.1+cpu -f https://download.pytorch.org/whl/torch_stable.html

# %%
# !git clone https://github.com/hwang595/PyTorch-parameter-server

# %%
# !wget www.di.ens.fr/~lelarge/MNIST.tar.gz
# !wget https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# !tar -zxvf MNIST.tar.gz
# !tar -zxvf cifar-10-python.tar.gz

# %%
# !bash ./src/run_pytorch_single.sh
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 0 3
# 1 3
# 2 3
# INFO:root:Added key: store_based_barrier_key:1 to store for rank: 2
# INFO:root:Added key: store_based_barrier_key:1 to store for rank: 1
# INFO:root:Added key: store_based_barrier_key:1 to store for rank: 0
# I am worker: 1 in all 2 workers, next step: 0
# INFO:root:Worker 1: starting training
# I am worker: 2 in all 2 workers, next step: 0
# INFO:root:Worker 2: starting training
# I am the master: the world size is 3, cur step: 1
# INFO:root:Master node is entering step: 0
# vinayak rank1 loss  = 2.3083555698394775batch id0current step0
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent2072.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent2224.0
# worker rank 1 total size sent520
# vinayak rank2 loss  = 2.3140580654144287batch id0current step0
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent2072.0
# worker rank 2 total size sent500
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent2224.0
# worker rank 2 total size sent520
# p index 2
# p index 2
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent102296.0
# worker rank 2 total size sent25520
# p index 3
# worker rank 2   ssded   torch.Size([50])
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent102568.0
# worker rank 2 total size sent25570
# total_byte_sent102296.0
# worker rank 1 total size sent25520
# p index 3
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent102568.0
# worker rank 1 total size sent25570
# p index 4
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent1702640.0p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent1702640.0
# worker rank 2 total size sent425570
# p index 5
#
# worker rank 2   ssded   torch.Size([500])
# worker rank 1 total size sent425570
# total_byte_sent1704712.0
# worker rank 2 total size sent426070
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent1704712.0
# worker rank 1 total size sent426070
# p index 6p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent1724784.0
# worker rank 2 total size sent431070
#
# worker rank 1   ssded   torch.Size([10, 500])
# total_byte_sent1724784.0
# worker rank 1 total size sent431070
# p index 7p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent1724896.0
# worker rank 1 total size sent431080
#
# worker rank 2   ssded   torch.Size([10])worker rank 1 total size sent431080
#
# total_byte_sent1724896.0
# worker rank 2 total size sent431080
# worker rank 2 total size sent431080
# INFO:root:Master node is entering step: 1
# /content/drive/MyDrive/DISML/Project/PyTorch-parameter-server/src/optim/sgd.py:91: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:1005.)
#   p.data.add_(-group['lr'], d_p)
# INFO:root:Worker: 2, Step: 0, ,  total recieve memoryt = 1724896.0 , total send memory = 1724896.0 , total time recive = 0.003714323043823242 , total_time send = 0.008000850677490234 , accuracy = 6.25
# /content/drive/MyDrive/DISML/Project/PyTorch-parameter-server/src/optim/sgd.py:91: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:1005.)
#   p.data.add_(-group['lr'], d_p)
# INFO:root:Worker: 1, Step: 0, ,  total recieve memoryt = 1724896.0 , total send memory = 1724896.0 , total time recive = 0.005156517028808594 , total_time send = 0.015482425689697266 , accuracy = 12.5
# vinayak rank1 loss  = 2.295804977416992batch id1current step1
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent1726968.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent1727120.0
# worker rank 1 total size sent520
# vinayak rank2 loss  = 2.2958993911743164batch id1current step1
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent1726968.0
# worker rank 2 total size sent500
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent1727120.0
# worker rank 2 total size sent520
# p index 2p index 2
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent1827192.0
# worker rank 1 total size sent25520
#
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent1827192.0
# worker rank 2 total size sent25520
# p index 3
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent1827464.0
# worker rank 1 total size sent25570
# p index 3
# worker rank 2   ssded   torch.Size([50])
# p index 4
# total_byte_sent1827464.0
# worker rank 2 total size sent25570
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent3427536.0
# worker rank 1 total size sent425570
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent3429608.0
# worker rank 1 total size sent426070
# p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent3427536.0
# worker rank 2 total size sent425570
# p index 5
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent3429608.0
# worker rank 2 total size sent426070
# p index 6
# worker rank 1   ssded   torch.Size([10, 500])p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent3449680.0
# worker rank 2 total size sent431070
#
# total_byte_sent3449680.0
# worker rank 1 total size sent431070
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent3449792.0
# worker rank 2 total size sent431080
# p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent3449792.0
# worker rank 1 total size sent431080
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# INFO:root:Master node is entering step: 2
# INFO:root:Worker: 1, Step: 1, ,  total recieve memoryt = 3449792.0 , total send memory = 3449792.0 , total time recive = 0.00980377197265625 , total_time send = 0.025101184844970703 , accuracy = 15.625
# INFO:root:Worker: 2, Step: 1, ,  total recieve memoryt = 3449792.0 , total send memory = 3449792.0 , total time recive = 0.008777856826782227 , total_time send = 0.01571369171142578 , accuracy = 12.5
# vinayak rank1 loss  = 2.2923243045806885batch id2current step2
# vinayak rank2 loss  = 2.2739827632904053batch id2current step2
# p index 0
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent3451864.0
# worker rank 1 total size sent500
# total_byte_sent3451864.0
# worker rank 2 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent3452016.0
# worker rank 1 total size sent520
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent3452016.0
# worker rank 2 total size sent520
# p index 2
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent3552088.0
# worker rank 2 total size sent25520
# p index 2
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent3552088.0
# worker rank 1 total size sent25520
# p index 3
# worker rank 2   ssded   torch.Size([50])
# total_byte_sent3552360.0
# worker rank 2 total size sent25570
# p index 3
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent3552360.0
# worker rank 1 total size sent25570
# p index 4
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent5152432.0p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent5152432.0
# worker rank 2 total size sent425570
#
# worker rank 1 total size sent425570
# p index 5
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent5154504.0
# worker rank 1 total size sent426070
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent5154504.0
# worker rank 2 total size sent426070
# p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent5174576.0
# worker rank 2 total size sent431070
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent5174688.0p index 6
#
# worker rank 1   ssded   torch.Size([10, 500])
# worker rank 2 total size sent431080
# total_byte_sent5174576.0
# worker rank 1 total size sent431070
# p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent5174688.0
# worker rank 1 total size sent431080
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# INFO:root:Master node is entering step: 3
# INFO:root:Worker: 1, Step: 2, ,  total recieve memoryt = 5174688.0 , total send memory = 5174688.0 , total time recive = 0.013529777526855469 , total_time send = 0.03062295913696289 , accuracy = 14.0625
# INFO:root:Worker: 2, Step: 2, ,  total recieve memoryt = 5174688.0 , total send memory = 5174688.0 , total time recive = 0.012732744216918945 , total_time send = 0.02209639549255371 , accuracy = 23.4375
# vinayak rank1 loss  = 2.305128335952759batch id3current step3
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent5176760.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent5176912.0
# worker rank 1 total size sent520
# vinayak rank2 loss  = 2.290360450744629batch id3current step3
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent5176760.0
# worker rank 2 total size sent500
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent5176912.0
# worker rank 2 total size sent520
# p index 2
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])p index 2
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent5276984.0
# worker rank 1 total size sent25520
#
# total_byte_sent5276984.0
# worker rank 2 total size sent25520
# p index 3
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent5277256.0
# worker rank 1 total size sent25570
# p index 3
# worker rank 2   ssded   torch.Size([50])
# total_byte_sent5277256.0
# worker rank 2 total size sent25570
# p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent6877328.0
# worker rank 2 total size sent425570
# p index 4
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent6877328.0
# worker rank 1 total size sent425570
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent6879400.0
# worker rank 1 total size sent426070
# p index 5
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent6879400.0
# worker rank 2 total size sent426070
# p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent6899472.0
# worker rank 2 total size sent431070
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent6899584.0
# p index 6
# worker rank 2 total size sent431080
# worker rank 1   ssded   torch.Size([10, 500])
# total_byte_sent6899472.0
# worker rank 1 total size sent431070
# p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent6899584.0
# worker rank 1 total size sent431080
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# INFO:root:Master node is entering step: 4
# INFO:root:Worker: 2, Step: 3, ,  total recieve memoryt = 6899584.0 , total send memory = 6899584.0 , total time recive = 0.015237808227539062 , total_time send = 0.028279781341552734 , accuracy = 12.5
# INFO:root:Worker: 1, Step: 3, ,  total recieve memoryt = 6899584.0 , total send memory = 6899584.0 , total time recive = 0.017955303192138672 , total_time send = 0.04142284393310547 , accuracy = 6.25
# vinayak rank1 loss  = 2.301708698272705batch id4current step4vinayak rank2 loss  = 2.2493910789489746batch id4current step4
#
# p index 0p index 0
#
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])worker rank 1   ssded   torch.Size([20, 1, 5, 5])
#
# total_byte_sent6901656.0total_byte_sent6901656.0
#
# worker rank 2 total size sent500worker rank 1 total size sent500
#
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent6901808.0
# worker rank 2 total size sent520
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent6901808.0
# worker rank 1 total size sent520
# p index 2
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent7001880.0
# worker rank 2 total size sent25520
# p index 2
# p index 3
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# worker rank 2   ssded   torch.Size([50])
# total_byte_sent7001880.0
# worker rank 1 total size sent25520
# total_byte_sent7002152.0
# worker rank 2 total size sent25570
# p index 3
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent7002152.0
# worker rank 1 total size sent25570
# p index 4
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent8602224.0
# worker rank 1 total size sent425570
# p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent8602224.0
# worker rank 2 total size sent425570
# p index 5
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent8604296.0
# worker rank 2 total size sent426070
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent8604296.0
# worker rank 1 total size sent426070
# p index 6
# worker rank 1   ssded   torch.Size([10, 500])
# total_byte_sent8624368.0
# worker rank 1 total size sent431070
# p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent8624480.0
# worker rank 1 total size sent431080
# p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent8624368.0
# worker rank 2 total size sent431070
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent8624480.0
# worker rank 2 total size sent431080
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# INFO:root:Master node is entering step: 5
# INFO:root:Worker: 2, Step: 4, ,  total recieve memoryt = 8624480.0 , total send memory = 8624480.0 , total time recive = 0.017823219299316406 , total_time send = 0.03449678421020508 , accuracy = 23.4375
# INFO:root:Worker: 1, Step: 4, ,  total recieve memoryt = 8624480.0 , total send memory = 8624480.0 , total time recive = 0.022334575653076172 , total_time send = 0.04698371887207031 , accuracy = 9.375
# vinayak rank2 loss  = 2.244206428527832batch id5current step5
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent8626552.0
# worker rank 2 total size sent500
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent8626704.0
# worker rank 2 total size sent520
# vinayak rank1 loss  = 2.2622363567352295batch id5current step5
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent8626552.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent8626704.0
# worker rank 1 total size sent520
# p index 2
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# p index 2
# total_byte_sent8726776.0
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])worker rank 1 total size sent25520
#
# total_byte_sent8726776.0p index 3
#
# worker rank 2 total size sent25520
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent8727048.0
# worker rank 1 total size sent25570
# p index 3
# worker rank 2   ssded   torch.Size([50])
# total_byte_sent8727048.0
# worker rank 2 total size sent25570
# p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent10327120.0
# worker rank 2 total size sent425570p index 4
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent10327120.0
# worker rank 1 total size sent425570
#
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent10329192.0
# worker rank 1 total size sent426070
# p index 5
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent10329192.0
# worker rank 2 total size sent426070
# p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent10349264.0
# worker rank 2 total size sent431070
# p index 6
# worker rank 1   ssded   torch.Size([10, 500])
# total_byte_sent10349264.0
# worker rank 1 total size sent431070
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent10349376.0
# worker rank 2 total size sent431080
# p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent10349376.0
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# worker rank 1 total size sent431080
# INFO:root:Master node is entering step: 6
# INFO:root:Worker: 1, Step: 5, ,  total recieve memoryt = 10349376.0 , total send memory = 10349376.0 , total time recive = 0.02727532386779785 , total_time send = 0.05418086051940918 , accuracy = 15.625
# INFO:root:Worker: 2, Step: 5, ,  total recieve memoryt = 10349376.0 , total send memory = 10349376.0 , total time recive = 0.021152973175048828 , total_time send = 0.044159889221191406 , accuracy = 23.4375
# vinayak rank1 loss  = 2.249889373779297batch id6current step6
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent10351448.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent10351600.0
# worker rank 1 total size sent520
# vinayak rank2 loss  = 2.269542694091797batch id6current step6
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent10351448.0
# worker rank 2 total size sent500
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent10351600.0
# worker rank 2 total size sent520
# p index 2
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent10451672.0
# worker rank 2 total size sent25520
# p index 3
# worker rank 2   ssded   torch.Size([50])
# total_byte_sent10451944.0
# worker rank 2 total size sent25570
# p index 2
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent10451672.0
# worker rank 1 total size sent25520
# p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent12052016.0
# worker rank 2 total size sent425570
# p index 3
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent10451944.0
# worker rank 1 total size sent25570
# p index 4
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent12052016.0
# worker rank 1 total size sent425570
# p index 5
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent12054088.0
# worker rank 2 total size sent426070
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent12054088.0
# worker rank 1 total size sent426070
# p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent12074160.0
# worker rank 2 total size sent431070
# p index 6
# worker rank 1   ssded   torch.Size([10, 500])
# total_byte_sent12074160.0
# worker rank 1 total size sent431070
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent12074272.0
# worker rank 2 total size sent431080
# p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent12074272.0
# worker rank 1 total size sent431080
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# INFO:root:Worker: 2, Step: 6, ,  total recieve memoryt = 12074272.0 , total send memory = 12074272.0 , total time recive = 0.025261640548706055 , total_time send = 0.05245471000671387 , accuracy = 28.125
# INFO:root:Master node is entering step: 7
# INFO:root:Worker: 1, Step: 6, ,  total recieve memoryt = 12074272.0 , total send memory = 12074272.0 , total time recive = 0.034293413162231445 , total_time send = 0.06428074836730957 , accuracy = 15.625
# vinayak rank2 loss  = 2.252979278564453batch id7current step7
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent12076344.0
# worker rank 2 total size sent500
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent12076496.0
# worker rank 2 total size sent520
# vinayak rank1 loss  = 2.2041382789611816batch id7current step7
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent12076344.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent12076496.0
# worker rank 1 total size sent520
# p index 2
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent12176568.0
# worker rank 1 total size sent25520
# p index 3
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent12176840.0p index 2
#
# worker rank 1 total size sent25570worker rank 2   ssded   torch.Size([50, 20, 5, 5])
#
# total_byte_sent12176568.0
# worker rank 2 total size sent25520
# p index 3
# p index 4worker rank 2   ssded   torch.Size([50])
#
# total_byte_sent12176840.0
# worker rank 2 total size sent25570
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent13776912.0
# worker rank 1 total size sent425570
# p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent13776912.0
# worker rank 2 total size sent425570
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent13778984.0
# worker rank 1 total size sent426070
# p index 5
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent13778984.0
# worker rank 2 total size sent426070
# p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent13799056.0
# worker rank 2 total size sent431070
# p index 6
# worker rank 1   ssded   torch.Size([10, 500])
# total_byte_sent13799056.0
# worker rank 1 total size sent431070
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent13799168.0
# worker rank 2 total size sent431080
# p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent13799168.0
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# worker rank 1 total size sent431080
# INFO:root:Master node is entering step: 8
# INFO:root:Worker: 1, Step: 7, ,  total recieve memoryt = 13799168.0 , total send memory = 13799168.0 , total time recive = 0.03740811347961426 , total_time send = 0.07039737701416016 , accuracy = 28.125
# INFO:root:Worker: 2, Step: 7, ,  total recieve memoryt = 13799168.0 , total send memory = 13799168.0 , total time recive = 0.028783082962036133 , total_time send = 0.06239032745361328 , accuracy = 17.1875
# vinayak rank2 loss  = 2.235701322555542batch id8current step8
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent13801240.0
# worker rank 2 total size sent500
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent13801392.0
# worker rank 2 total size sent520
# vinayak rank1 loss  = 2.1910135746002197batch id8current step8
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent13801240.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent13801392.0
# worker rank 1 total size sent520
# p index 2
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent13901464.0
# worker rank 2 total size sent25520
# p index 2
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent13901464.0
# worker rank 1 total size sent25520
# p index 3
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent13901736.0
# worker rank 1 total size sent25570
# p index 3
# worker rank 2   ssded   torch.Size([50])p index 4
#
# total_byte_sent13901736.0worker rank 1   ssded   torch.Size([500, 800])
#
# worker rank 2 total size sent25570
# total_byte_sent15501808.0
# worker rank 1 total size sent425570
# p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent15501808.0
# worker rank 2 total size sent425570
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent15503880.0
# worker rank 1 total size sent426070
# p index 5p index 6
# worker rank 1   ssded   torch.Size([10, 500])
# total_byte_sent15523952.0
# worker rank 1 total size sent431070
#
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent15503880.0
# worker rank 2 total size sent426070
# p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent15523952.0
# worker rank 2 total size sent431070
# p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent15524064.0
# worker rank 1 total size sent431080
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent15524064.0
# worker rank 2 total size sent431080
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# INFO:root:Master node is entering step: 9
# INFO:root:Worker: 1, Step: 8, ,  total recieve memoryt = 15524064.0 , total send memory = 15524064.0 , total time recive = 0.042222023010253906 , total_time send = 0.08632612228393555 , accuracy = 28.125
# INFO:root:Worker: 2, Step: 8, ,  total recieve memoryt = 15524064.0 , total send memory = 15524064.0 , total time recive = 0.03255486488342285 , total_time send = 0.0811614990234375 , accuracy = 34.375
# vinayak rank2 loss  = 2.224975347518921batch id9current step9
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent15526136.0
# worker rank 2 total size sent500
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent15526288.0
# worker rank 2 total size sent520
# vinayak rank1 loss  = 2.1774559020996094batch id9current step9
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent15526136.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent15526288.0
# worker rank 1 total size sent520
# p index 2
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent15626360.0
# worker rank 1 total size sent25520
# p index 3p index 2
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])
#
# worker rank 1   ssded   torch.Size([50])total_byte_sent15626360.0
# worker rank 2 total size sent25520
#
# total_byte_sent15626632.0
# worker rank 1 total size sent25570
# p index 3
# worker rank 2   ssded   torch.Size([50])
# total_byte_sent15626632.0
# worker rank 2 total size sent25570
# p index 4
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent17226704.0
# worker rank 1 total size sent425570p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent17226704.0
# worker rank 2 total size sent425570
#
# p index 5
# worker rank 2   ssded   torch.Size([500])
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent17228776.0
# worker rank 1 total size sent426070
# total_byte_sent17228776.0
# worker rank 2 total size sent426070
# p index 6
# worker rank 1   ssded   torch.Size([10, 500])p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent17248848.0
# worker rank 2 total size sent431070
#
# total_byte_sent17248848.0
# worker rank 1 total size sent431070
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent17248960.0
# worker rank 2 total size sent431080
# p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent17248960.0
# worker rank 1 total size sent431080
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# INFO:root:Master node is entering step: 10
# INFO:root:Worker: 1, Step: 9, ,  total recieve memoryt = 17248960.0 , total send memory = 17248960.0 , total time recive = 0.04531979560852051 , total_time send = 0.09235692024230957 , accuracy = 31.25
# INFO:root:Worker: 2, Step: 9, ,  total recieve memoryt = 17248960.0 , total send memory = 17248960.0 , total time recive = 0.03642725944519043 , total_time send = 0.08940434455871582 , accuracy = 25.0
# vinayak rank1 loss  = 2.1785078048706055batch id10current step10
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent17251032.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent17251184.0
# worker rank 1 total size sent520
# vinayak rank2 loss  = 2.203279972076416batch id10current step10
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent17251032.0
# worker rank 2 total size sent500
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent17251184.0
# worker rank 2 total size sent520
# p index 2
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent17351256.0
# worker rank 2 total size sent25520
# p index 2
# p index 3
# worker rank 2   ssded   torch.Size([50])
# total_byte_sent17351528.0
# worker rank 2 total size sent25570
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent17351256.0
# worker rank 1 total size sent25520
# p index 3
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent17351528.0
# worker rank 1 total size sent25570
# p index 4
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent18951600.0
# worker rank 1 total size sent425570
# p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent18951600.0
# worker rank 2 total size sent425570
# p index 5
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent18953672.0
# worker rank 2 total size sent426070
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent18953672.0
# worker rank 1 total size sent426070
# p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent18973744.0
# worker rank 2 total size sent431070
# p index 6
# worker rank 1   ssded   torch.Size([10, 500])
# total_byte_sent18973744.0
# worker rank 1 total size sent431070
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent18973856.0
# worker rank 2 total size sent431080
# p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent18973856.0
# worker rank 1 total size sent431080
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# INFO:root:Master node is entering step: 11
# INFO:root:Worker: 2, Step: 10, ,  total recieve memoryt = 18973856.0 , total send memory = 18973856.0 , total time recive = 0.03953123092651367 , total_time send = 0.09549188613891602 , accuracy = 31.25
# INFO:root:Worker: 1, Step: 10, ,  total recieve memoryt = 18973856.0 , total send memory = 18973856.0 , total time recive = 0.04937624931335449 , total_time send = 0.10110616683959961 , accuracy = 32.8125
# vinayak rank2 loss  = 2.1680400371551514batch id11current step11
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent18975928.0
# worker rank 2 total size sent500
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent18976080.0
# worker rank 2 total size sent520
# vinayak rank1 loss  = 2.1340487003326416batch id11current step11
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent18975928.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent18976080.0
# worker rank 1 total size sent520
# p index 2
# p index 2
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent19076152.0
# worker rank 1 total size sent25520
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent19076152.0p index 3
#
# worker rank 2 total size sent25520
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent19076424.0
# worker rank 1 total size sent25570
# p index 3
# worker rank 2   ssded   torch.Size([50])
# total_byte_sent19076424.0
# worker rank 2 total size sent25570
# p index 4
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent20676496.0
# worker rank 1 total size sent425570p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent20676496.0
# worker rank 2 total size sent425570
#
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent20678568.0
# worker rank 1 total size sent426070
# p index 5
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent20678568.0
# worker rank 2 total size sent426070
# p index 6
# worker rank 1   ssded   torch.Size([10, 500])
# total_byte_sent20698640.0
# worker rank 1 total size sent431070
# p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent20698640.0
# worker rank 2 total size sent431070
# p index 7p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent20698752.0
# worker rank 1 total size sent431080
#
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent20698752.0
# worker rank 2 total size sent431080
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# INFO:root:Master node is entering step: 12
# INFO:root:Worker: 1, Step: 11, ,  total recieve memoryt = 20698752.0 , total send memory = 20698752.0 , total time recive = 0.0526881217956543 , total_time send = 0.10729122161865234 , accuracy = 35.9375
# INFO:root:Worker: 2, Step: 11, ,  total recieve memoryt = 20698752.0 , total send memory = 20698752.0 , total time recive = 0.04376626014709473 , total_time send = 0.10323739051818848 , accuracy = 25.0
# vinayak rank2 loss  = 2.1628165245056152batch id12current step12
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent20700824.0
# worker rank 2 total size sent500
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent20700976.0
# worker rank 2 total size sent520
# vinayak rank1 loss  = 2.0949935913085938batch id12current step12
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent20700824.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent20700976.0
# worker rank 1 total size sent520
# p index 2
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent20801048.0
# worker rank 1 total size sent25520
# p index 3
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent20801320.0p index 2
#
# worker rank 1 total size sent25570worker rank 2   ssded   torch.Size([50, 20, 5, 5])
#
# total_byte_sent20801048.0
# worker rank 2 total size sent25520
# p index 3
# worker rank 2   ssded   torch.Size([50])
# total_byte_sent20801320.0
# worker rank 2 total size sent25570
# p index 4
# worker rank 1   ssded   torch.Size([500, 800])p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent22401392.0
# worker rank 2 total size sent425570
# p index 5
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent22403464.0
# worker rank 2 total size sent426070
#
# total_byte_sent22401392.0
# worker rank 1 total size sent425570
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent22403464.0
# worker rank 1 total size sent426070
# p index 6p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent22423536.0
# worker rank 2 total size sent431070
#
# worker rank 1   ssded   torch.Size([10, 500])
# total_byte_sent22423536.0
# worker rank 1 total size sent431070
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent22423648.0
# worker rank 2 total size sent431080
# p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent22423648.0
# worker rank 1 total size sent431080
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# INFO:root:Master node is entering step: 13
# INFO:root:Worker: 2, Step: 12, ,  total recieve memoryt = 22423648.0 , total send memory = 22423648.0 , total time recive = 0.046916961669921875 , total_time send = 0.11472249031066895 , accuracy = 29.6875
# INFO:root:Worker: 1, Step: 12, ,  total recieve memoryt = 22423648.0 , total send memory = 22423648.0 , total time recive = 0.05705428123474121 , total_time send = 0.11328363418579102 , accuracy = 39.0625
# vinayak rank2 loss  = 2.1190311908721924batch id13current step13
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent22425720.0
# worker rank 2 total size sent500
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent22425872.0
# worker rank 2 total size sent520
# vinayak rank1 loss  = 2.0285794734954834batch id13current step13
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent22425720.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent22425872.0
# worker rank 1 total size sent520
# p index 2
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent22525944.0
# worker rank 1 total size sent25520
# p index 3
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent22526216.0
# worker rank 1 total size sent25570
# p index 2
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent22525944.0
# worker rank 2 total size sent25520
# p index 3
# worker rank 2   ssded   torch.Size([50])
# total_byte_sent22526216.0
# worker rank 2 total size sent25570
# p index 4
# worker rank 2   ssded   torch.Size([500, 800])p index 4
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent24126288.0
# worker rank 1 total size sent425570
#
# total_byte_sent24126288.0
# worker rank 2 total size sent425570
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent24128360.0
# worker rank 1 total size sent426070
# p index 5
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent24128360.0
# worker rank 2 total size sent426070
# p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent24148432.0
# worker rank 2 total size sent431070
# p index 6
# worker rank 1   ssded   torch.Size([10, 500])p index 7
# worker rank 2   ssded   torch.Size([10])
#
# total_byte_sent24148544.0
# worker rank 2 total size sent431080
# total_byte_sent24148432.0
# worker rank 1 total size sent431070
# p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent24148544.0
# worker rank 1 total size sent431080
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# INFO:root:Master node is entering step: 14
# INFO:root:Worker: 1, Step: 13, ,  total recieve memoryt = 24148544.0 , total send memory = 24148544.0 , total time recive = 0.06032586097717285 , total_time send = 0.11911725997924805 , accuracy = 57.8125
# INFO:root:Worker: 2, Step: 13, ,  total recieve memoryt = 24148544.0 , total send memory = 24148544.0 , total time recive = 0.04932975769042969 , total_time send = 0.12430238723754883 , accuracy = 40.625
# vinayak rank2 loss  = 2.0989556312561035batch id14current step14
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent24150616.0
# worker rank 2 total size sent500
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent24150768.0
# worker rank 2 total size sent520
# vinayak rank1 loss  = 2.017777919769287batch id14current step14
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent24150616.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent24150768.0
# worker rank 1 total size sent520
# p index 2
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent24250840.0
# worker rank 1 total size sent25520
# p index 2
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent24250840.0
# worker rank 2 total size sent25520
# p index 3
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent24251112.0
# worker rank 1 total size sent25570
# p index 3
# worker rank 2   ssded   torch.Size([50])
# total_byte_sent24251112.0
# worker rank 2 total size sent25570
# p index 4
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent25851184.0
# worker rank 1 total size sent425570
# p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent25851184.0
# worker rank 2 total size sent425570
# p index 5
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent25853256.0
# worker rank 2 total size sent426070
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent25853256.0
# worker rank 1 total size sent426070
# p index 6
# worker rank 1   ssded   torch.Size([10, 500])
# total_byte_sent25873328.0
# worker rank 1 total size sent431070
# p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent25873328.0
# worker rank 2 total size sent431070
# p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent25873440.0
# worker rank 1 total size sent431080
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent25873440.0
# worker rank 2 total size sent431080
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# INFO:root:Master node is entering step: 15
# INFO:root:Worker: 1, Step: 14, ,  total recieve memoryt = 25873440.0 , total send memory = 25873440.0 , total time recive = 0.0636892318725586 , total_time send = 0.12533044815063477 , accuracy = 59.375
# INFO:root:Worker: 2, Step: 14, ,  total recieve memoryt = 25873440.0 , total send memory = 25873440.0 , total time recive = 0.053524017333984375 , total_time send = 0.13238096237182617 , accuracy = 48.4375
# vinayak rank2 loss  = 2.0719382762908936batch id15current step15
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent25875512.0
# worker rank 2 total size sent500
# vinayak rank1 loss  = 1.9656931161880493batch id15current step15
# p index 1p index 0
#
# worker rank 2   ssded   torch.Size([20])worker rank 1   ssded   torch.Size([20, 1, 5, 5])
#
# total_byte_sent25875664.0
# worker rank 2 total size sent520total_byte_sent25875512.0
# worker rank 1 total size sent500
#
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent25875664.0
# worker rank 1 total size sent520
# p index 2
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent25975736.0
# worker rank 1 total size sent25520
# p index 2
# p index 3worker rank 2   ssded   torch.Size([50, 20, 5, 5])
#
# total_byte_sent25975736.0
# worker rank 2 total size sent25520
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent25976008.0
# worker rank 1 total size sent25570
# p index 3
# worker rank 2   ssded   torch.Size([50])
# total_byte_sent25976008.0
# worker rank 2 total size sent25570
# p index 4
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent27576080.0
# p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent27576080.0
# worker rank 2 total size sent425570
# p index 5
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent27578152.0
# worker rank 2 total size sent426070
# worker rank 1 total size sent425570
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent27578152.0
# worker rank 1 total size sent426070
# p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent27598224.0
# worker rank 2 total size sent431070
# p index 6
# worker rank 1   ssded   torch.Size([10, 500])
# total_byte_sent27598224.0
# worker rank 1 total size sent431070
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent27598336.0
# worker rank 2 total size sent431080
# p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent27598336.0
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# worker rank 1 total size sent431080
# INFO:root:Master node is entering step: 16
# INFO:root:Worker: 1, Step: 15, ,  total recieve memoryt = 27598336.0 , total send memory = 27598336.0 , total time recive = 0.06705331802368164 , total_time send = 0.13100767135620117 , accuracy = 59.375
# INFO:root:Worker: 2, Step: 15, ,  total recieve memoryt = 27598336.0 , total send memory = 27598336.0 , total time recive = 0.05776524543762207 , total_time send = 0.13822388648986816 , accuracy = 42.1875
# vinayak rank1 loss  = 1.8873103857040405batch id16current step16
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent27600408.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent27600560.0
# worker rank 1 total size sent520
# vinayak rank2 loss  = 2.026421308517456batch id16current step16
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent27600408.0
# worker rank 2 total size sent500
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent27600560.0
# worker rank 2 total size sent520
# p index 2
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent27700632.0
# worker rank 2 total size sent25520
# p index 3
# worker rank 2   ssded   torch.Size([50])
# total_byte_sent27700904.0
# worker rank 2 total size sent25570
# p index 2
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent27700632.0
# worker rank 1 total size sent25520
# p index 3
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent27700904.0
# worker rank 1 total size sent25570
# p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent29300976.0
# worker rank 2 total size sent425570
# p index 5
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent29303048.0
# worker rank 2 total size sent426070
# p index 4
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent29300976.0
# worker rank 1 total size sent425570
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent29303048.0
# worker rank 1 total size sent426070
# p index 6p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent29323120.0
# worker rank 2 total size sent431070
#
# worker rank 1   ssded   torch.Size([10, 500])
# total_byte_sent29323120.0
# worker rank 1 total size sent431070
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent29323232.0
# worker rank 2 total size sent431080
# p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent29323232.0
# worker rank 1 total size sent431080
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# INFO:root:Master node is entering step: 17
# INFO:root:Worker: 1, Step: 16, ,  total recieve memoryt = 29323232.0 , total send memory = 29323232.0 , total time recive = 0.07028651237487793 , total_time send = 0.14315485954284668 , accuracy = 53.125
# INFO:root:Worker: 2, Step: 16, ,  total recieve memoryt = 29323232.0 , total send memory = 29323232.0 , total time recive = 0.0613863468170166 , total_time send = 0.14461541175842285 , accuracy = 48.4375
# vinayak rank1 loss  = 1.8277443647384644batch id17current step17
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent29325304.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent29325456.0
# worker rank 1 total size sent520
# vinayak rank2 loss  = 2.014099597930908batch id17current step17
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent29325304.0
# worker rank 2 total size sent500
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent29325456.0
# worker rank 2 total size sent520
# p index 2
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent29425528.0
# worker rank 1 total size sent25520
# p index 2p index 3
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent29425800.0
# worker rank 1 total size sent25570
#
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent29425528.0
# worker rank 2 total size sent25520
# p index 3
# worker rank 2   ssded   torch.Size([50])
# total_byte_sent29425800.0
# worker rank 2 total size sent25570
# p index 4
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent31025872.0
# worker rank 1 total size sent425570
# p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent31025872.0
# worker rank 2 total size sent425570
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent31027944.0
# worker rank 1 total size sent426070
# p index 5
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent31027944.0
# worker rank 2 total size sent426070
# p index 6
# worker rank 1   ssded   torch.Size([10, 500])
# total_byte_sent31048016.0
# worker rank 1 total size sent431070
# p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent31048016.0
# worker rank 2 total size sent431070
# p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent31048128.0
# worker rank 1 total size sent431080
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent31048128.0
# worker rank 2 total size sent431080
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# INFO:root:Master node is entering step: 18
# INFO:root:Worker: 1, Step: 17, ,  total recieve memoryt = 31048128.0 , total send memory = 31048128.0 , total time recive = 0.07387781143188477 , total_time send = 0.15763235092163086 , accuracy = 50.0
# INFO:root:Worker: 2, Step: 17, ,  total recieve memoryt = 31048128.0 , total send memory = 31048128.0 , total time recive = 0.06561589241027832 , total_time send = 0.1562175750732422 , accuracy = 56.25
# vinayak rank1 loss  = 1.9037423133850098batch id18current step18
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent31050200.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent31050352.0
# worker rank 1 total size sent520
# vinayak rank2 loss  = 1.945761799812317batch id18current step18
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent31050200.0
# worker rank 2 total size sent500
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent31050352.0
# worker rank 2 total size sent520
# p index 2
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent31150424.0
# worker rank 2 total size sent25520
# p index 3
# worker rank 2   ssded   torch.Size([50])
# total_byte_sent31150696.0
# worker rank 2 total size sent25570
# p index 2
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent31150424.0
# worker rank 1 total size sent25520
# p index 3
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent31150696.0
# worker rank 1 total size sent25570
# p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent32750768.0
# worker rank 2 total size sent425570
# p index 4
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent32750768.0
# worker rank 1 total size sent425570
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent32752840.0
# worker rank 1 total size sent426070
# p index 5
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent32752840.0
# worker rank 2 total size sent426070
# p index 6
# ...
# p index 6p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent51746880.0
# worker rank 1 total size sent431080
#
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent51746768.0
# worker rank 2 total size sent431070
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent51746880.0
# worker rank 2 total size sent431080
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# INFO:root:Master node is entering step: 30
# INFO:root:Worker: 2, Step: 29, ,  total recieve memoryt = 51746880.0 , total send memory = 51746880.0 , total time recive = 0.13161087036132812 , total_time send = 0.2739448547363281 , accuracy = 70.3125
# INFO:root:Worker: 1, Step: 29, ,  total recieve memoryt = 51746880.0 , total send memory = 51746880.0 , total time recive = 0.13130569458007812 , total_time send = 0.28020548820495605 , accuracy = 70.3125
# vinayak rank2 loss  = 0.8567104935646057batch id30current step30
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent51748952.0
# worker rank 2 total size sent500
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent51749104.0
# worker rank 2 total size sent520
# vinayak rank1 loss  = 1.0193997621536255batch id30current step30
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent51748952.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent51749104.0
# worker rank 1 total size sent520
# p index 2
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent51849176.0
# worker rank 2 total size sent25520
# p index 2
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent51849176.0
# worker rank 1 total size sent25520
# p index 3
# worker rank 2   ssded   torch.Size([50])
# total_byte_sent51849448.0
# worker rank 2 total size sent25570
# p index 3
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent51849448.0
# worker rank 1 total size sent25570
# p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent53449520.0p index 4
# worker rank 2 total size sent425570
#
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent53449520.0
# worker rank 1 total size sent425570
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent53451592.0
# worker rank 1 total size sent426070
# p index 5
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent53451592.0
# worker rank 2 total size sent426070
# p index 6
# worker rank 1   ssded   torch.Size([10, 500])
# total_byte_sent53471664.0
# worker rank 1 total size sent431070
# p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent53471664.0
# worker rank 2 total size sent431070
# p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent53471776.0
# worker rank 1 total size sent431080
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent53471776.0
# worker rank 2 total size sent431080
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# INFO:root:Master node is entering step: 31
# INFO:root:Worker: 1, Step: 30, ,  total recieve memoryt = 53471776.0 , total send memory = 53471776.0 , total time recive = 0.1344156265258789 , total_time send = 0.2854466438293457 , accuracy = 64.0625
# INFO:root:Worker: 2, Step: 30, ,  total recieve memoryt = 53471776.0 , total send memory = 53471776.0 , total time recive = 0.13593435287475586 , total_time send = 0.2802464962005615 , accuracy = 89.0625
# vinayak rank1 loss  = 0.6338539123535156batch id31current step31
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent53473848.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent53474000.0
# worker rank 1 total size sent520
# vinayak rank2 loss  = 1.2218424081802368batch id31current step31
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent53473848.0
# worker rank 2 total size sent500
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent53474000.0
# worker rank 2 total size sent520
# p index 2
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent53574072.0
# worker rank 2 total size sent25520p index 2
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
#
# total_byte_sent53574072.0
# worker rank 1 total size sent25520
# p index 3
# worker rank 2   ssded   torch.Size([50])
# total_byte_sent53574344.0
# worker rank 2 total size sent25570
# p index 3
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent53574344.0
# worker rank 1 total size sent25570
# p index 4p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent55174416.0
# worker rank 2 total size sent425570
#
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent55174416.0
# worker rank 1 total size sent425570
# p index 5
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent55176488.0
# worker rank 2 total size sent426070
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent55176488.0
# worker rank 1 total size sent426070
# p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent55196560.0
# worker rank 2 total size sent431070
# p index 6
# worker rank 1   ssded   torch.Size([10, 500])
# total_byte_sent55196560.0
# worker rank 1 total size sent431070
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent55196672.0
# worker rank 2 total size sent431080
# p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent55196672.0
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# worker rank 1 total size sent431080
# INFO:root:Master node is entering step: 32
# INFO:root:Worker: 1, Step: 31, ,  total recieve memoryt = 55196672.0 , total send memory = 55196672.0 , total time recive = 0.1374673843383789 , total_time send = 0.3001668453216553 , accuracy = 87.5
# INFO:root:Worker: 2, Step: 31, ,  total recieve memoryt = 55196672.0 , total send memory = 55196672.0 , total time recive = 0.13993501663208008 , total_time send = 0.28713107109069824 , accuracy = 65.625
# vinayak rank2 loss  = 0.9600820541381836batch id32current step32
# vinayak rank1 loss  = 0.5396541953086853batch id32current step32
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent55198744.0p index 0
#
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# worker rank 2 total size sent500
# total_byte_sent55198744.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent55198896.0
# worker rank 1 total size sent520
# p index 1p index 2
#
# worker rank 2   ssded   torch.Size([20])
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent55198896.0total_byte_sent55298968.0
#
# worker rank 2 total size sent520
# worker rank 1 total size sent25520
# p index 2
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent55298968.0
# worker rank 2 total size sent25520
# p index 3p index 3
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent55299240.0
# worker rank 1 total size sent25570
#
# worker rank 2   ssded   torch.Size([50])
# total_byte_sent55299240.0
# worker rank 2 total size sent25570
# p index 4p index 4
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent56899312.0
# worker rank 1 total size sent425570
#
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent56899312.0
# worker rank 2 total size sent425570
# p index 5
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent56901384.0
# worker rank 2 total size sent426070
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent56901384.0
# worker rank 1 total size sent426070
# p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent56921456.0
# worker rank 2 total size sent431070
# p index 6
# worker rank 1   ssded   torch.Size([10, 500])
# total_byte_sent56921456.0
# worker rank 1 total size sent431070
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent56921568.0
# worker rank 2 total size sent431080
# p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent56921568.0
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# worker rank 1 total size sent431080
# INFO:root:Master node is entering step: 33
# INFO:root:Worker: 2, Step: 32, ,  total recieve memoryt = 56921568.0 , total send memory = 56921568.0 , total time recive = 0.14338469505310059 , total_time send = 0.2932162284851074 , accuracy = 67.1875
# INFO:root:Worker: 1, Step: 32, ,  total recieve memoryt = 56921568.0 , total send memory = 56921568.0 , total time recive = 0.1421966552734375 , total_time send = 0.306255578994751 , accuracy = 84.375
# vinayak rank2 loss  = 0.7857598662376404batch id33current step33
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent56923640.0
# worker rank 2 total size sent500
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent56923792.0
# worker rank 2 total size sent520
# vinayak rank1 loss  = 0.9983614683151245batch id33current step33
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent56923640.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent56923792.0
# worker rank 1 total size sent520
# p index 2
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent57023864.0
# worker rank 1 total size sent25520
# p index 3
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent57024136.0
# worker rank 1 total size sent25570
# p index 2
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent57023864.0
# worker rank 2 total size sent25520
# p index 3
# worker rank 2   ssded   torch.Size([50])
# total_byte_sent57024136.0
# worker rank 2 total size sent25570
# p index 4
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent58624208.0
# worker rank 1 total size sent425570
# p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent58624208.0
# worker rank 2 total size sent425570
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent58626280.0
# worker rank 1 total size sent426070
# p index 5
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent58626280.0
# worker rank 2 total size sent426070
# p index 6
# worker rank 1   ssded   torch.Size([10, 500])
# total_byte_sent58646352.0
# worker rank 1 total size sent431070
# p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent58646352.0
# worker rank 2 total size sent431070
# p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent58646464.0
# worker rank 1 total size sent431080
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent58646464.0
# worker rank 2 total size sent431080
# worker rank 1 total size sent431080
# worker rank 2 total size sent431080
# INFO:root:Master node is entering step: 34
# INFO:root:Worker: 2, Step: 33, ,  total recieve memoryt = 58646464.0 , total send memory = 58646464.0 , total time recive = 0.14737224578857422 , total_time send = 0.3095986843109131 , accuracy = 71.875
# INFO:root:Worker: 1, Step: 33, ,  total recieve memoryt = 58646464.0 , total send memory = 58646464.0 , total time recive = 0.14731192588806152 , total_time send = 0.3122129440307617 , accuracy = 65.625
# vinayak rank1 loss  = 0.8180407881736755batch id34current step34
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent58648536.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent58648688.0
# worker rank 1 total size sent520
# vinayak rank2 loss  = 0.7072959542274475batch id34current step34
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent58648536.0
# worker rank 2 total size sent500
# p index 2
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent58748760.0
# worker rank 1 total size sent25520
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent58648688.0
# worker rank 2 total size sent520
# p index 3
# worker rank 1   ssded   torch.Size([50])
# total_byte_sent58749032.0
# worker rank 1 total size sent25570
# p index 2
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent58748760.0
# worker rank 2 total size sent25520
# p index 3
# worker rank 2   ssded   torch.Size([50])
# total_byte_sent58749032.0
# worker rank 2 total size sent25570
# p index 4
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent60349104.0
# worker rank 1 total size sent425570
# p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent60349104.0
# worker rank 2 total size sent425570
# p index 5
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent60351176.0
# worker rank 2 total size sent426070
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent60351176.0
# worker rank 1 total size sent426070
# p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent60371248.0
# worker rank 2 total size sent431070
# p index 6
# worker rank 1   ssded   torch.Size([10, 500])
# total_byte_sent60371248.0
# worker rank 1 total size sent431070
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent60371360.0
# worker rank 2 total size sent431080
# p index 7
# worker rank 1   ssded   torch.Size([10])worker rank 2 total size sent431080
#
# total_byte_sent60371360.0
# worker rank 1 total size sent431080
# worker rank 1 total size sent431080
# INFO:root:Master node is entering step: 35
# INFO:root:Worker: 2, Step: 34, ,  total recieve memoryt = 60371360.0 , total send memory = 60371360.0 , total time recive = 0.15079784393310547 , total_time send = 0.3150455951690674 , accuracy = 75.0
# INFO:root:Worker: 1, Step: 34, ,  total recieve memoryt = 60371360.0 , total send memory = 60371360.0 , total time recive = 0.151900053024292 , total_time send = 0.32384276390075684 , accuracy = 75.0
# vinayak rank2 loss  = 0.823640763759613batch id35current step35
# p index 0
# worker rank 2   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent60373432.0
# worker rank 2 total size sent500
# p index 1
# worker rank 2   ssded   torch.Size([20])
# total_byte_sent60373584.0
# worker rank 2 total size sent520
# vinayak rank1 loss  = 0.7007248997688293batch id35current step35
# p index 0
# worker rank 1   ssded   torch.Size([20, 1, 5, 5])
# total_byte_sent60373432.0
# worker rank 1 total size sent500
# p index 1
# worker rank 1   ssded   torch.Size([20])
# total_byte_sent60373584.0
# worker rank 1 total size sent520
# p index 2
# worker rank 1   ssded   torch.Size([50, 20, 5, 5])
# total_byte_sent60473656.0
# worker rank 1 total size sent25520
# p index 3
# p index 2
# worker rank 1   ssded   torch.Size([50])
# worker rank 2   ssded   torch.Size([50, 20, 5, 5])total_byte_sent60473928.0
#
# worker rank 1 total size sent25570
# total_byte_sent60473656.0
# worker rank 2 total size sent25520
# p index 3
# worker rank 2   ssded   torch.Size([50])
# total_byte_sent60473928.0
# worker rank 2 total size sent25570
# p index 4
# worker rank 1   ssded   torch.Size([500, 800])
# total_byte_sent62074000.0
# worker rank 1 total size sent425570
# p index 4
# worker rank 2   ssded   torch.Size([500, 800])
# total_byte_sent62074000.0
# worker rank 2 total size sent425570
# p index 5
# worker rank 1   ssded   torch.Size([500])
# total_byte_sent62076072.0
# worker rank 1 total size sent426070
# p index 5
# worker rank 2   ssded   torch.Size([500])
# total_byte_sent62076072.0
# worker rank 2 total size sent426070
# p index 6
# worker rank 1   ssded   torch.Size([10, 500])
# total_byte_sent62096144.0
# worker rank 1 total size sent431070
# p index 6
# worker rank 2   ssded   torch.Size([10, 500])
# total_byte_sent62096144.0
# worker rank 2 total size sent431070
# p index 7
# worker rank 1   ssded   torch.Size([10])
# total_byte_sent62096256.0
# worker rank 1 total size sent431080
# worker rank 1 total size sent431080
# p index 7
# worker rank 2   ssded   torch.Size([10])
# total_byte_sent62096256.0
# worker rank 2 total size sent431080
# worker rank 2 total size sent431080
# INFO:root:Master node is entering step: 36
# INFO:root:Worker: 1, Step: 35, ,  total recieve memoryt = 62096256.0 , total send memory = 62096256.0 , total time recive = 0.1604621410369873 , total_time send = 0.33459997177124023 , accuracy = 75.0
# INFO:root:Worker: 2, Step: 35, ,  total recieve memoryt = 62096256.0 , total send memory = 62096256.0 , total time recive = 0.1580336093902588 , total_time send = 0.33074498176574707 , accuracy = 75.0
# Killing subprocess 588
# Killing subprocess 589
# Killing subprocess 590
# Main process received SIGINT, exiting

# %%
# !bash ./src/evaluate_pytorch.sh
